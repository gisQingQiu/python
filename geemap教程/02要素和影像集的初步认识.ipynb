# %%
import ee
import geemap

# %%
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map = geemap.Map()
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %% [markdown]
# # 本地矢量数据导入 gee 云端
# ### 方法一：使用函数 geemap.shp_to_ee(filepath)
# ### 方法二：将本地矢量数据上传至 Earth Engine 资产，再调用

# %%
# geemap.shp_to_ee 用法
local_shp = r"D:\学科作业\geemap\数据\江西省县级行政区划.shp"
roi = geemap.shp_to_ee(local_shp)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map.addLayer(roi, {'color': 'pink'}, "江西省(本地矢量数据)")
Map.centerObject(roi, 6)    # 将江西省设置为地图中心，并缩放到适当级别
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=812.0, center=[27.602071762034374, 115.71097041794854], controls=(WidgetControl(options=['position'…

# %%
assets = 'projects/ee-qingqiu760/assets/jiangxi'    # 资产路径
roi = ee.FeatureCollection(assets)    # 从资产中加载江西省矢量数据
Map.addLayer(roi, {'color': 'white'}, "江西省（资产）")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# No such comm: 785bedc5a5f94784b8a628e72376ff0a
# No such comm: 785bedc5a5f94784b8a628e72376ff0a
# No such comm: 785bedc5a5f94784b8a628e72376ff0a
# No such comm: 785bedc5a5f94784b8a628e72376ff0a
# No such comm: 785bedc5a5f94784b8a628e72376ff0a
# No such comm: 785bedc5a5f94784b8a628e72376ff0a
# No such comm: 785bedc5a5f94784b8a628e72376ff0a

# %% [markdown]
# # ee.FeatureCollection() 用法
# ## 查阅官方文档学习
# ## https://developers.google.com/earth-engine/apidocs/ee-featurecollection

# %%
roi.getInfo()    # 打印江西省矢量数据的信息

county = roi.aggregate_array('NAME')    # 此为ee.List，非Python List
print(type(county))

# 将ee.List转换为Python List
county_list = county.getInfo()    # 获取ee.List的内容
county_list
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'ee.ee_list.List'>
# ['安福县',
#  '安义县',
#  '安源区',
#  '安远县',
#  '昌江区',
#  '崇仁县',
#  '崇义县',
#  '大余县',
#  '德安县',
#  '德兴市',
#  '定南县',
#  '东湖区',
#  '东乡县',
#  '都昌县',
#  '分宜县',
#  '丰城市',
#  '奉新县',
#  '浮梁县',
#  '赣县',
#  '高安市',
#  '共青城市',
#  '广昌县',
#  '广丰区',
#  '贵溪市',
#  '横峰县',
#  '湖口县',
#  '会昌县',
#  '吉安县',
#  '吉水县',
#  '吉州区',
#  '金溪县',
#  '进贤县',
#  '井冈山市',
#  '靖安县',
#  '九江县',
#  '乐安县',
#  '乐平市',
#  '黎川县',
#  '莲花县',
#  '临川区',
#  '龙南县',
#  '芦溪县',
#  '庐山区',
#  '南昌县',
#  '南城县',
#  '南丰县',
#  '南康区',
#  '宁都县',
#  '彭泽县',
#  '鄱阳县',
#  '铅山县',
#  '青山湖区',
#  '青原区',
#  '青云谱区',
#  '全南县',
#  '瑞昌市',
#  '瑞金市',
#  '上高县',
#  '上栗县',
#  '上饶县',
#  '上犹县',
#  '石城县',
#  '遂川县',
#  '泰和县',
#  '铜鼓县',
#  '湾里区',
#  '万安县',
#  '万年县',
#  '万载县',
#  '武宁县',
#  '婺源县',
#  '西湖区',
#  '峡江县',
#  '湘东区',
#  '新干县',
#  '新建县',
#  '信丰县',
#  '信州区',
#  '星子县',
#  '兴国县',
#  '修水县',
#  '寻乌县',
#  '浔阳区',
#  '宜丰县',
#  '宜黄县',
#  '弋阳县',
#  '永丰县',
#  '永新县',
#  '永修县',
#  '于都县',
#  '余干县',
#  '余江县',
#  '渝水区',
#  '玉山县',
#  '袁州区',
#  '月湖区',
#  '章贡区',
#  '樟树市',
#  '珠山区',
#  '资溪县']

# %% [markdown]
# ### 获取江西省的边界坐标

# %%
bounds = roi.bounds()
bounds_info = bounds.getInfo()    # 获取边界信息
bounds_info
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'geodesic': False,
#  'type': 'Polygon',
#  'coordinates': [[[113.57163613558352, 24.48771526917336],
#    [118.48205175883177, 24.48771526917336],
#    [118.48205175883177, 30.07954837020023],
#    [113.57163613558352, 30.07954837020023],
#    [113.57163613558352, 24.48771526917336]]]}

# %% [markdown]
# ### 按属性筛选矢量数据

# %%
# 筛选出于都县, ee.Filter 为过滤器，geemap 中的另一种数据类型
yudu = roi.filter(ee.Filter.eq('NAME', '于都县'))    
Map.addLayer(yudu, {'color': 'blue'}, "于都县")
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=27459.0, center=[29.42524498547202, 115.65307617187501], controls=(WidgetControl(options=['position…

# %% [markdown]
# ### 将 feature collection 转换为其他对象

# %%
# 不同的数据类型有不同的用法，需要熟练掌握 geemap 中各种数据类型的转换
print(type(roi))    # 输出类型为 ee.FeatureCollection
first_feature = roi.first()    # 获取第一个 feature
print(type(first_feature))    # 输出类型为 ee.Element
geometry = first_feature.geometry()    # 获取第一个 feature 的几何对象
print(type(geometry))    # 输出类型为 ee.Geometry
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'ee.featurecollection.FeatureCollection'>
# <class 'ee.element.Element'>
# <class 'ee.geometry.Geometry'>

# %% [markdown]
# # ee.ImageCollection 的用法
# ## 查阅官方文档学习
# ## https://developers.google.com/earth-engine/apidocs/ee-imagecollection

# %% [markdown]
# ### 调用影像集

# %%
landsat = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")    # 加载 Landsat 8 图像集合
Map.addLayer(landsat, {}, "Landsat 8")    # 添加 Landsat 8 图像集合到地图
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=56008.0, center=[26.046912801683984, 115.96618652343751], controls=(WidgetControl(options=['positio…
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df
# No such comm: 9f20b5f91c21485482e4fe50d346b2df

# %% [markdown]
# ## 影像集的特点
# 1. 影像集就是一个影像的集合，里面有许许多多的影像
# 2. 影像集的每张影像中都有其属性，记录了如 **拍摄时间(ee.Date)** 和 **拍摄地点(bounds)** 等信息，可以通过这些信息筛选出需要的影像
# 3. **光学遥感卫星**影像集中的影像一般而言是没有经过云层处理的，需要通过**云量过滤**或者**去云函数**处理

# %%
# Landsat 8 去云函数
def maskL8sr(image):
    # Bit 0 - Fill
    # Bit 1 - Dilated Cloud
    # Bit 2 - Cirrus
    # Bit 3 - Cloud
    # Bit 4 - Cloud Shadow
    qaMask = image.select('QA_PIXEL').bitwiseAnd(int('11111', 2)).eq(0)
    saturationMask = image.select('QA_RADSAT').eq(0)

    # Apply the scaling factors to the appropriate bands.
    opticalBands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
    thermalBands = image.select('ST_B.*').multiply(0.00341802).add(149.0)

    # Replace the original bands with the scaled ones and apply the masks.
    return image.addBands(opticalBands, None, True) \
    .addBands(thermalBands, None, True) \
    .updateMask(qaMask) \
    .updateMask(saturationMask)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# landsat 8 影像筛选
Landsat8 = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2") \
                .filterBounds(yudu) \
                .filterDate(ee.Date('2024-01-01'), ee.Date('2024-12-31')) \
                .map(maskL8sr)
                # .map(lambda image: image.clip(yudu))    # 裁剪影像
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
visualization = {
    'bands': ['SR_B4', 'SR_B3', 'SR_B2'],
    'min': 0.0,
    'max': 0.3,
}    # 可视化参数
Map.addLayer(Landsat8, visualization, "Landsat 8 (2024)")
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=28237.0, center=[25.63657407787705, 115.40039062500001], controls=(WidgetControl(options=['position…

# %% [markdown]
# ### 从结果中可以看出 filterBounds 的特性
# ### 它并不会将影像集中的影像按研究区裁剪，只是过滤出和研究区有交集的影像

# %%
Landsat8.getInfo()    # 打印 Landsat 8 图像集合的信息
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'ImageCollection',
#  'bands': [],
#  'version': 1756558956824653,
#  'id': 'LANDSAT/LC08/C02/T1_L2',
#  'properties': {'type_name': 'ImageCollection',
#   'keywords': ['cfmask',
#    'cloud',
#    'fmask',
#    'global',
#    'l8sr',
#    'landsat',
#    'lasrc',
#    'lst',
#    'reflectance',
#    'sr',
#    'usgs'],
#   'visualization_1_bands': 'SR_B5,SR_B4,SR_B3',
#   'thumb': 'https://mw1.google.com/ges/dd/images/LANDSAT_SR_thumb.png',
#   'visualization_1_max': '30000.0',
#   'description': '<p>This dataset contains atmospherically corrected\nsurface reflectance and land surface temperature derived from the data\nproduced by the Landsat 8 OLI/TIRS sensors.\nThese images contain 5 visible and near-infrared (VNIR) bands and\n2 short-wave infrared (SWIR) bands processed to orthorectified surface\nreflectance, and one thermal infrared (TIR) band processed to orthorectified\nsurface temperature. They also contain intermediate bands used in\ncalculation of the ST products, as well as QA bands.</p><p>Landsat 8 SR products are created with the Land Surface Reflectance Code\n(LaSRC). All Collection 2 ST products are created with a single-channel\nalgorithm jointly created by the Rochester Institute of Technology (RIT) and\nNational Aeronautics and Space Administration (NASA)\nJet Propulsion Laboratory (JPL).</p><p>Strips of collected data are packaged into overlapping &quot;scenes&quot; covering approximately\n170km x 183km using a <a href="https://landsat.gsfc.nasa.gov/about/worldwide-reference-system">standardized reference grid</a>.</p><p>Some assets have only SR data, in which case ST bands are present but empty.\nFor assets with both ST and SR bands, &#39;PROCESSING_LEVEL&#39; is set to &#39;L2SP&#39;.\nFor assets with only SR bands, &#39;PROCESSING_LEVEL&#39; is set to &#39;L2SR&#39;.</p><p><a href="/earth-engine/guides/landsat">Additional documentation and usage examples.</a></p><p>Data provider notes:</p><ul><li><p>Data products must contain both optical and thermal data to be\nsuccessfully processed to surface temperature, as ASTER NDVI is\nrequired to temporally adjust the ASTER GED product to the target Landsat\nscene. Therefore, night time acquisitions cannot be processed to\nsurface temperature.</p></li><li><p>A known error exists in the surface temperature retrievals relative\nto clouds and possibly cloud shadows. The characterization of these\nissues has been documented by\n<a href="https://doi.org/10.3390/rs61111244">Cook et al., (2014)</a>.</p></li></ul><p><b>Provider: <a href="https://www.usgs.gov/core-science-systems/nli/landsat/landsat-collection-2-level-2-science-products">USGS</a></b><br><p><b>Resolution</b><br>30 meters\n</p><p><b>Revisit Interval</b><br>\n  16 days\n</p><p><b>Bands</b><table class="eecat"><tr><th scope="col">Name</th><th scope="col">Units</th><th scope="col">Min</th><th scope="col">Max</th><th scope="col">Scale</th><th scope="col">Offset</th><th scope="col">Wavelength</th><th scope="col">Description</th></tr><tr><td>SR_B1</td><td></td><td>\n          1\n</td><td>\n          65455\n</td><td>2.75e-05</td><td>-0.2</td><td>0.435-0.451 &mu;m</td><td><p>Band 1 (ultra blue, coastal aerosol) surface reflectance</p></td></tr><tr><td>SR_B2</td><td></td><td>\n          1\n</td><td>\n          65455\n</td><td>2.75e-05</td><td>-0.2</td><td>0.452-0.512 &mu;m</td><td><p>Band 2 (blue) surface reflectance</p></td></tr><tr><td>SR_B3</td><td></td><td>\n          1\n</td><td>\n          65455\n</td><td>2.75e-05</td><td>-0.2</td><td>0.533-0.590 &mu;m</td><td><p>Band 3 (green) surface reflectance</p></td></tr><tr><td>SR_B4</td><td></td><td>\n          1\n</td><td>\n          65455\n</td><td>2.75e-05</td><td>-0.2</td><td>0.636-0.673 &mu;m</td><td><p>Band 4 (red) surface reflectance</p></td></tr><tr><td>SR_B5</td><td></td><td>\n          1\n</td><td>\n          65455\n</td><td>2.75e-05</td><td>-0.2</td><td>0.851-0.879 &mu;m</td><td><p>Band 5 (near infrared) surface reflectance</p></td></tr><tr><td>SR_B6</td><td></td><td>\n          1\n</td><td>\n          65455\n</td><td>2.75e-05</td><td>-0.2</td><td>1.566-1.651 &mu;m</td><td><p>Band 6 (shortwave infrared 1) surface reflectance</p></td></tr><tr><td>SR_B7</td><td></td><td>\n          1\n</td><td>\n          65455\n</td><td>2.75e-05</td><td>-0.2</td><td>2.107-2.294 &mu;m</td><td><p>Band 7 (shortwave infrared 2) surface reflectance</p></td></tr><tr><td>SR_QA_AEROSOL</td><td></td><td></td><td></td><td></td><td></td><td></td><td><p>Aerosol att ...
#   'source_tags': ['landsat', 'usgs'],
#   'visualization_1_name': 'Near Infrared (543)',
#   'visualization_0_max': '30000.0',
#   'title': 'USGS Landsat 8 Level 2, Collection 2, Tier 1',
#   'product_tags': ['global',
#    'sr',
#    'reflectance',
#    'l8sr',
#    'lst',
#    'cloud',
#    'lasrc',
#    'fmask',
#    'cfmask',
#    'lc08'],
#   'provider': 'USGS',
#   'visualization_1_min': '0.0',
#   'visualization_0_min': '0.0',
#   'visualization_0_name': 'True Color (432)',
#   'date_range': [1365638400000, 1654560000000],
#   'visualization_2_bands': 'SR_B7,SR_B5,SR_B3',
#   'visualization_2_name': 'Shortwave Infrared (753)',
#   'period': 0,
#   'visualization_2_min': '0.0',
#   'provider_url': 'https://www.usgs.gov/core-science-systems/nli/landsat/landsat-collection-2-level-2-science-products',
#   'sample': 'https://mw1.google.com/ges/dd/images/LANDSAT_SR_sample.png',
#   'tags': ['cfmask',
#    'cloud',
#    'fmask',
#    'global',
#    'l8sr',
#    'landsat',
#    'lasrc',
#    'lst',
#    'reflectance',
#    'sr',
#    'usgs'],
#   'visualization_2_max': '30000.0',
#   'visualization_0_bands': 'SR_B4,SR_B3,SR_B2'},
#  'features': [{'type': 'Image',
#    'bands': [{'id': 'SR_B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'SR_B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'SR_B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'SR_B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'SR_B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'SR_B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'SR_B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'SR_QA_AEROSOL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'ST_B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': 149,
#       'max': 372.9999407},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'ST_ATRAN',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'ST_CDIST',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'ST_DRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'ST_EMIS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'ST_EMSD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'ST_QA',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'ST_TRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'ST_URAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'QA_PIXEL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]},
#     {'id': 'QA_RADSAT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 267285, 0, -30, 2992215]}],
#    'version': 1705189124176658,
#    'id': 'LANDSAT/LC08/C02/T1_L2/LC08_121042_20240105',
#    'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000',
#     'WRS_TYPE': 2,
#     'REFLECTANCE_ADD_BAND_1': -0.2,
#     'REFLECTANCE_ADD_BAND_2': -0.2,
#     'DATUM': 'WGS84',
#     'REFLECTANCE_ADD_BAND_3': -0.2,
#     'REFLECTANCE_ADD_BAND_4': -0.2,
#     'REFLECTANCE_ADD_BAND_5': -0.2,
#     'REFLECTANCE_ADD_BAND_6': -0.2,
#     'REFLECTANCE_ADD_BAND_7': -0.2,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[116.94964582822611, 26.669644545795165],
#       [116.94520666073264, 26.670639851041425],
#       [116.70321390044408, 26.720600109590045],
#       [116.08539546053285, 26.84607289781916],
#       [115.42176050218023, 26.97751999390491],
#       [115.15434203971387, 27.02950963330905],
#       [115.12539065515737, 27.03509092297973],
#       [115.12431293961589, 27.03507656667053],
#       [115.12309823198792, 27.030432855947684],
#       [114.9200047338152, 26.186531478720475],
#       [114.7213060566687, 25.35049597948454],
#       [114.71108737179851, 25.307195224718285],
#       [114.71111699473937, 25.305619349763102],
#       [115.04337806338816, 25.23970716748432],
#       [116.10785311576068, 25.02295450150823],
#       [116.50928291803959, 24.93901074852622],
#       [116.6156030471164, 25.360195776716075],
#       [116.72820511704903, 25.803654601822196],
#       [116.82072982358707, 26.16571473518638],
#       [116.92519116672715, 26.572986258778947],
#       [116.94899278804371, 26.6664103697838],
#       [116.94964582822611, 26.669644545795165]]},
#     'REFLECTIVE_SAMPLES': 7681,
#     'GROUND_CONTROL_POINTS_VERSION': 5,
#     'SUN_AZIMUTH': 152.21897347,
#     'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#     'UTM_ZONE': 50,
#     'DATE_ACQUIRED': '2024-01-05',
#     'ELLIPSOID': 'WGS84',
#     'system:time_end': 1704422712403,
#     'DATA_SOURCE_PRESSURE': 'Calculated',
#     'LANDSAT_PRODUCT_ID': 'LC08_L2SP_121042_20240105_20240112_02_T1',
#     'STATION_ID': 'LGN',
#     'TEMPERATURE_ADD_BAND_ST_B10': 149,
#     'DATA_SOURCE_REANALYSIS': 'GEOS-5 IT',
#     'REFLECTANCE_MULT_BAND_7': 2.75e-05,
#     'system:time_start': 1704422712403,
#     'REFLECTANCE_MULT_BAND_6': 2.75e-05,
#     'L1_PROCESSING_LEVEL': 'L1TP',
#     'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.3.1',
#     'L1_DATE_PRODUCT_GENERATED': '2024-01-12T22:03:07Z',
#     'ORIENTATION': 'NORTH_UP',
#     'REFLECTANCE_MULT_BAND_1': 2.75e-05,
#     'WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_3': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_2': 2.75e-05,
#     'TARGET_WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_5': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_4': 2.75e-05,
#     'THERMAL_LINES': 7821,
#     'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#     'GRID_CELL_SIZE_THERMAL': 30,
#     'IMAGE_QUALITY_TIRS': 9,
#     'TRUNCATION_OLI': 'UPPER',
#     'NADIR_OFFNADIR': 'NADIR',
#     'CLOUD_COVER': 50.99,
#     'REQUEST_ID': '1838490_02431',
#     'EARTH_SUN_DISTANCE': 0.9833183,
#     'GEOMETRIC_RMSE_VERIFY': 5.823,
#     'TIRS_SSM_MODEL': 'FINAL',
#     'COLLECTION_CATEGORY': 'T1',
#     'SCENE_CENTER_TIME': '02:45:12.4035519Z',
#     'GRID_CELL_SIZE_REFLECTIVE': 30,
#     'SUN_ELEVATION': 36.01293612,
#     'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.5.0',
#     'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941,
#     'CLOUD_COVER_LAND': 50.99,
#     'GEOMETRIC_RMSE_MODEL': 6.115,
#     'ROLL_ANGLE': -0.001,
#     'COLLECTION_NUMBER': 2,
#     'DATE_PRODUCT_GENERATED': 1705098466000,
#     'L1_REQUEST_ID': '1838490_02431',
#     'DATA_SOURCE_OZONE': 'VIIRS',
#     'SATURATION_BAND_1': 'N',
#     'DATA_SOURCE_WATER_VAPOR': 'VIIRS',
#     'SATURATION_BAND_2': 'N',
#     'SATURATION_BAND_3': 'N',
#     'IMAGE_QUALITY_OLI': 9,
#     'SATURATION_BAND_4': 'N',
#     'LANDSAT_SCENE_ID': 'LC81210422024005LGN00',
#     'SATURATION_BAND_5': 'N',
#     'MAP_PROJECTION': 'UTM',
#     'SATURATION_BAND_6': 'Y',
#     'SENSOR_ID': 'OLI_TIRS',
#     'SATURATION_BAND_7': 'Y',
#     'SATURATION_BAND_8': 'N',
#     'WRS_PATH': 121,
#     'SATURATION_BAND_9': 'N',
#     'TARGET_WRS_PATH': 121,
#     'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_16.3.1',
#     'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802,
#     'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_121042_20240105_20240112_02_T1',
#     'PROCESSING_LEVEL': 'L2SP',
#     'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.6.0',
#     'GROUND_CONTROL_POINTS_MODEL': 328,
#     'SPACECRAFT_ID': 'LANDSAT_8',
#     'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418,
#     'GEOMETRIC_RMSE_MODEL_Y': 4.723,
#     'REFLECTIVE_LINES': 7821,
#     'GEOMETRIC_RMSE_MODEL_X': 3.884,
#     'THERMAL_SAMPLES': 7681,
#     'system:asset_size': 1081210517,
#     'DATA_SOURCE_AIR_TEMPERATURE': 'VIIRS',
#     'GROUND_CONTROL_POINTS_VERIFY': 135,
#     'system:index': 'LC08_121042_20240105'}},
#   {'type': 'Image',
#    'bands': [{'id': 'SR_B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'SR_B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'SR_B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'SR_B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'SR_B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'SR_B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'SR_B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'SR_QA_AEROSOL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'ST_B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': 149,
#       'max': 372.9999407},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'ST_ATRAN',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'ST_CDIST',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'ST_DRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'ST_EMIS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'ST_EMSD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'ST_QA',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'ST_TRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'ST_URAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'QA_PIXEL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]},
#     {'id': 'QA_RADSAT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7671, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 265785, 0, -30, 2992215]}],
#    'version': 1712322201997452,
#    'id': 'LANDSAT/LC08/C02/T1_L2/LC08_121042_20240325',
#    'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000',
#     'WRS_TYPE': 2,
#     'REFLECTANCE_ADD_BAND_1': -0.2,
#     'REFLECTANCE_ADD_BAND_2': -0.2,
#     'DATUM': 'WGS84',
#     'REFLECTANCE_ADD_BAND_3': -0.2,
#     'REFLECTANCE_ADD_BAND_4': -0.2,
#     'REFLECTANCE_ADD_BAND_5': -0.2,
#     'REFLECTANCE_ADD_BAND_6': -0.2,
#     'REFLECTANCE_ADD_BAND_7': -0.2,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[116.48954692905882, 24.94006185511726],
#       [116.49002325123489, 24.94093864390184],
#       [116.49165539675057, 24.94698723004046],
#       [116.58797946006823, 25.328965749115763],
#       [116.808110047881, 26.194593112375102],
#       [116.81643084131512, 26.227200970670427],
#       [116.85887901823166, 26.393300609348362],
#       [116.90399683967242, 26.569406117795527],
#       [116.91406152223658, 26.609234193201477],
#       [116.9221761646088, 26.64147397587346],
#       [116.92909822489794, 26.670219346438095],
#       [116.92909750611722, 26.671295457611674],
#       [116.8623649571547, 26.685107101501757],
#       [115.64992705519015, 26.929789645244217],
#       [115.10683971120616, 27.035654909090884],
#       [115.10569931749295, 27.035639507099077],
#       [115.10381104905414, 27.028095526026295],
#       [115.09935564028908, 27.009912906271772],
#       [114.89359240612063, 26.15324768295951],
#       [114.69291691478017, 25.30715696807886],
#       [114.69294391194889, 25.305730888974427],
#       [116.48954692905882, 24.94006185511726]]},
#     'REFLECTIVE_SAMPLES': 7671,
#     'GROUND_CONTROL_POINTS_VERSION': 5,
#     'SUN_AZIMUTH': 131.62642446,
#     'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#     'UTM_ZONE': 50,
#     'DATE_ACQUIRED': '2024-03-25',
#     'ELLIPSOID': 'WGS84',
#     'system:time_end': 1711334688213,
#     'DATA_SOURCE_PRESSURE': 'Calculated',
#     'LANDSAT_PRODUCT_ID': 'LC08_L2SP_121042_20240325_20240403_02_T1',
#     'STATION_ID': 'LGN',
#     'TEMPERATURE_ADD_BAND_ST_B10': 149,
#     'DATA_SOURCE_REANALYSIS': 'GEOS-5 IT',
#     'REFLECTANCE_MULT_BAND_7': 2.75e-05,
#     'system:time_start': 1711334688213,
#     'REFLECTANCE_MULT_BAND_6': 2.75e-05,
#     'L1_PROCESSING_LEVEL': 'L1TP',
#     'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'L1_DATE_PRODUCT_GENERATED': '2024-04-03T09:23:08Z',
#     'ORIENTATION': 'NORTH_UP',
#     'REFLECTANCE_MULT_BAND_1': 2.75e-05,
#     'WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_3': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_2': 2.75e-05,
#     'TARGET_WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_5': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_4': 2.75e-05,
#     'THERMAL_LINES': 7821,
#     'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#     'GRID_CELL_SIZE_THERMAL': 30,
#     'IMAGE_QUALITY_TIRS': 9,
#     'TRUNCATION_OLI': 'UPPER',
#     'NADIR_OFFNADIR': 'NADIR',
#     'CLOUD_COVER': 71.94,
#     'REQUEST_ID': '1868991_00036',
#     'EARTH_SUN_DISTANCE': 0.9972528,
#     'TIRS_SSM_MODEL': 'FINAL',
#     'COLLECTION_CATEGORY': 'T1',
#     'SCENE_CENTER_TIME': '02:44:48.2131920Z',
#     'GRID_CELL_SIZE_REFLECTIVE': 30,
#     'SUN_ELEVATION': 56.37293145,
#     'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.5.0',
#     'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941,
#     'CLOUD_COVER_LAND': 71.94,
#     'GEOMETRIC_RMSE_MODEL': 6.585,
#     'ROLL_ANGLE': -0.001,
#     'COLLECTION_NUMBER': 2,
#     'DATE_PRODUCT_GENERATED': 1712137509000,
#     'L1_REQUEST_ID': '1868991_00036',
#     'DATA_SOURCE_OZONE': 'VIIRS',
#     'SATURATION_BAND_1': 'Y',
#     'DATA_SOURCE_WATER_VAPOR': 'VIIRS',
#     'SATURATION_BAND_2': 'Y',
#     'SATURATION_BAND_3': 'Y',
#     'IMAGE_QUALITY_OLI': 9,
#     'SATURATION_BAND_4': 'Y',
#     'LANDSAT_SCENE_ID': 'LC81210422024085LGN00',
#     'SATURATION_BAND_5': 'Y',
#     'MAP_PROJECTION': 'UTM',
#     'SATURATION_BAND_6': 'N',
#     'SENSOR_ID': 'OLI_TIRS',
#     'SATURATION_BAND_7': 'Y',
#     'SATURATION_BAND_8': 'N',
#     'WRS_PATH': 121,
#     'SATURATION_BAND_9': 'N',
#     'TARGET_WRS_PATH': 121,
#     'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802,
#     'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_121042_20240325_20240403_02_T1',
#     'PROCESSING_LEVEL': 'L2SP',
#     'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.6.0',
#     'GROUND_CONTROL_POINTS_MODEL': 142,
#     'SPACECRAFT_ID': 'LANDSAT_8',
#     'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418,
#     'GEOMETRIC_RMSE_MODEL_Y': 4.875,
#     'REFLECTIVE_LINES': 7821,
#     'GEOMETRIC_RMSE_MODEL_X': 4.427,
#     'THERMAL_SAMPLES': 7671,
#     'system:asset_size': 1172625405,
#     'DATA_SOURCE_AIR_TEMPERATURE': 'VIIRS',
#     'system:index': 'LC08_121042_20240325'}},
#   {'type': 'Image',
#    'bands': [{'id': 'SR_B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'SR_B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'SR_B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'SR_B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'SR_B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'SR_B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'SR_B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'SR_QA_AEROSOL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'ST_B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': 149,
#       'max': 372.9999407},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'ST_ATRAN',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'ST_CDIST',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'ST_DRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'ST_EMIS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'ST_EMSD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'ST_QA',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'ST_TRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'ST_URAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'QA_PIXEL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]},
#     {'id': 'QA_RADSAT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7681, 7821],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992215]}],
#    'version': 1713564962039595,
#    'id': 'LANDSAT/LC08/C02/T1_L2/LC08_121042_20240410',
#    'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000',
#     'WRS_TYPE': 2,
#     'REFLECTANCE_ADD_BAND_1': -0.2,
#     'REFLECTANCE_ADD_BAND_2': -0.2,
#     'DATUM': 'WGS84',
#     'REFLECTANCE_ADD_BAND_3': -0.2,
#     'REFLECTANCE_ADD_BAND_4': -0.2,
#     'REFLECTANCE_ADD_BAND_5': -0.2,
#     'REFLECTANCE_ADD_BAND_6': -0.2,
#     'REFLECTANCE_ADD_BAND_7': -0.2,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[115.10714392410163, 27.031319665948935],
#       [115.086077819844, 27.03537401695417],
#       [115.084924503477, 27.035358315689827],
#       [115.07869616269191, 27.011509757350794],
#       [114.87301379836374, 26.154705144605135],
#       [114.67206762449302, 25.30701692145164],
#       [114.67209453258862, 25.305610483971],
#       [114.97807994862217, 25.245056353898573],
#       [116.4655983090713, 24.940655566515538],
#       [116.46975983818419, 24.93982793088319],
#       [116.47129200987109, 24.945509844718558],
#       [116.55096433780732, 25.262212150408516],
#       [116.78557120775672, 26.18571238029007],
#       [116.83872641289646, 26.393821079947607],
#       [116.88786768909722, 26.585920460501168],
#       [116.90889827483333, 26.669664780531104],
#       [116.90889719656046, 26.670970593293962],
#       [116.86161773102268, 26.680754413370593],
#       [115.85281285132703, 26.885273031720892],
#       [115.10714392410163, 27.031319665948935]]},
#     'REFLECTIVE_SAMPLES': 7681,
#     'GROUND_CONTROL_POINTS_VERSION': 5,
#     'SUN_AZIMUTH': 124.71920542,
#     'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#     'UTM_ZONE': 50,
#     'DATE_ACQUIRED': '2024-04-10',
#     'ELLIPSOID': 'WGS84',
#     'system:time_end': 1712717083755,
#     'DATA_SOURCE_PRESSURE': 'Calculated',
#     'LANDSAT_PRODUCT_ID': 'LC08_L2SP_121042_20240410_20240419_02_T1',
#     'STATION_ID': 'LGN',
#     'TEMPERATURE_ADD_BAND_ST_B10': 149,
#     'DATA_SOURCE_REANALYSIS': 'GEOS-5 IT',
#     'REFLECTANCE_MULT_BAND_7': 2.75e-05,
#     'system:time_start': 1712717083755,
#     'REFLECTANCE_MULT_BAND_6': 2.75e-05,
#     'L1_PROCESSING_LEVEL': 'L1TP',
#     'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'L1_DATE_PRODUCT_GENERATED': '2024-04-19T00:27:53Z',
#     'ORIENTATION': 'NORTH_UP',
#     'REFLECTANCE_MULT_BAND_1': 2.75e-05,
#     'WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_3': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_2': 2.75e-05,
#     'TARGET_WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_5': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_4': 2.75e-05,
#     'THERMAL_LINES': 7821,
#     'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#     'GRID_CELL_SIZE_THERMAL': 30,
#     'IMAGE_QUALITY_TIRS': 9,
#     'TRUNCATION_OLI': 'UPPER',
#     'NADIR_OFFNADIR': 'NADIR',
#     'CLOUD_COVER': 87.04,
#     'REQUEST_ID': '1875851_00036',
#     'EARTH_SUN_DISTANCE': 1.001891,
#     'TIRS_SSM_MODEL': 'FINAL',
#     'COLLECTION_CATEGORY': 'T1',
#     'SCENE_CENTER_TIME': '02:44:43.7551479Z',
#     'GRID_CELL_SIZE_REFLECTIVE': 30,
#     'SUN_ELEVATION': 61.49068652,
#     'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.5.0',
#     'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941,
#     'CLOUD_COVER_LAND': 87.04,
#     'GEOMETRIC_RMSE_MODEL': 6.681,
#     'ROLL_ANGLE': -0.001,
#     'COLLECTION_NUMBER': 2,
#     'DATE_PRODUCT_GENERATED': 1713487812000,
#     'L1_REQUEST_ID': '1875851_00036',
#     'DATA_SOURCE_OZONE': 'VIIRS',
#     'SATURATION_BAND_1': 'Y',
#     'DATA_SOURCE_WATER_VAPOR': 'VIIRS',
#     'SATURATION_BAND_2': 'Y',
#     'SATURATION_BAND_3': 'Y',
#     'IMAGE_QUALITY_OLI': 9,
#     'SATURATION_BAND_4': 'Y',
#     'LANDSAT_SCENE_ID': 'LC81210422024101LGN00',
#     'SATURATION_BAND_5': 'Y',
#     'MAP_PROJECTION': 'UTM',
#     'SATURATION_BAND_6': 'Y',
#     'SENSOR_ID': 'OLI_TIRS',
#     'SATURATION_BAND_7': 'Y',
#     'SATURATION_BAND_8': 'N',
#     'WRS_PATH': 121,
#     'SATURATION_BAND_9': 'N',
#     'TARGET_WRS_PATH': 121,
#     'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802,
#     'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_121042_20240410_20240419_02_T1',
#     'PROCESSING_LEVEL': 'L2SP',
#     'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.6.0',
#     'GROUND_CONTROL_POINTS_MODEL': 106,
#     'SPACECRAFT_ID': 'LANDSAT_8',
#     'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418,
#     'GEOMETRIC_RMSE_MODEL_Y': 4.857,
#     'REFLECTIVE_LINES': 7821,
#     'GEOMETRIC_RMSE_MODEL_X': 4.588,
#     'THERMAL_SAMPLES': 7681,
#     'system:asset_size': 1099539969,
#     'DATA_SOURCE_AIR_TEMPERATURE': 'VIIRS',
#     'system:index': 'LC08_121042_20240410'}},
#   {'type': 'Image',
#    'bands': [{'id': 'SR_B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'SR_B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'SR_B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'SR_B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'SR_B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'SR_B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'SR_B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'SR_QA_AEROSOL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'ST_B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': 149,
#       'max': 372.9999407},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'ST_ATRAN',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'ST_CDIST',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'ST_DRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'ST_EMIS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'ST_EMSD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'ST_QA',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'ST_TRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'ST_URAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'QA_PIXEL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]},
#     {'id': 'QA_RADSAT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7671, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263385, 0, -30, 2992515]}],
#    'version': 1715647526116778,
#    'id': 'LANDSAT/LC08/C02/T1_L2/LC08_121042_20240426',
#    'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000',
#     'WRS_TYPE': 2,
#     'REFLECTANCE_ADD_BAND_1': -0.2,
#     'REFLECTANCE_ADD_BAND_2': -0.2,
#     'DATUM': 'WGS84',
#     'REFLECTANCE_ADD_BAND_3': -0.2,
#     'REFLECTANCE_ADD_BAND_4': -0.2,
#     'REFLECTANCE_ADD_BAND_5': -0.2,
#     'REFLECTANCE_ADD_BAND_6': -0.2,
#     'REFLECTANCE_ADD_BAND_7': -0.2,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[114.66723600413302, 25.3060722631076],
#       [114.67253176621792, 25.30495735686901],
#       [115.35969048994282, 25.16799105392425],
#       [116.4642425684121, 24.940401084782273],
#       [116.46546271735218, 24.94040546657149],
#       [116.46720334531317, 24.946861023629154],
#       [116.78076993215228, 26.184350716697235],
#       [116.83511245472316, 26.397067531082918],
#       [116.88364894147323, 26.58672964214764],
#       [116.89805983124032, 26.643895379642455],
#       [116.9043762203417, 26.669120227812652],
#       [116.90437442318239, 26.671280827881034],
#       [116.86252322783835, 26.67994267576377],
#       [116.69810404348131, 26.71381766416286],
#       [116.25657207716354, 26.80374010296078],
#       [115.08089822553215, 27.035732492471496],
#       [115.08015925927572, 27.034357218395304],
#       [115.07476799468834, 27.01420764127131],
#       [114.86934301905279, 26.15857714303564],
#       [114.66723600413302, 25.3060722631076]]},
#     'REFLECTIVE_SAMPLES': 7671,
#     'GROUND_CONTROL_POINTS_VERSION': 5,
#     'SUN_AZIMUTH': 115.99731461,
#     'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#     'UTM_ZONE': 50,
#     'DATE_ACQUIRED': '2024-04-26',
#     'ELLIPSOID': 'WGS84',
#     'system:time_end': 1714099474593,
#     'DATA_SOURCE_PRESSURE': 'Calculated',
#     'LANDSAT_PRODUCT_ID': 'LC08_L2SP_121042_20240426_20240510_02_T1',
#     'STATION_ID': 'LGN',
#     'TEMPERATURE_ADD_BAND_ST_B10': 149,
#     'DATA_SOURCE_REANALYSIS': 'GEOS-5 IT',
#     'REFLECTANCE_MULT_BAND_7': 2.75e-05,
#     'system:time_start': 1714099474593,
#     'REFLECTANCE_MULT_BAND_6': 2.75e-05,
#     'L1_PROCESSING_LEVEL': 'L1TP',
#     'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'L1_DATE_PRODUCT_GENERATED': '2024-05-10T19:18:03Z',
#     'ORIENTATION': 'NORTH_UP',
#     'REFLECTANCE_MULT_BAND_1': 2.75e-05,
#     'WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_3': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_2': 2.75e-05,
#     'TARGET_WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_5': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_4': 2.75e-05,
#     'THERMAL_LINES': 7831,
#     'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#     'GRID_CELL_SIZE_THERMAL': 30,
#     'IMAGE_QUALITY_TIRS': 9,
#     'TRUNCATION_OLI': 'UPPER',
#     'NADIR_OFFNADIR': 'NADIR',
#     'CLOUD_COVER': 66.94,
#     'REQUEST_ID': '1883414_00036',
#     'EARTH_SUN_DISTANCE': 1.0062523,
#     'TIRS_SSM_MODEL': 'FINAL',
#     'COLLECTION_CATEGORY': 'T1',
#     'SCENE_CENTER_TIME': '02:44:34.5937129Z',
#     'GRID_CELL_SIZE_REFLECTIVE': 30,
#     'SUN_ELEVATION': 65.54455592,
#     'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.5.0',
#     'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941,
#     'CLOUD_COVER_LAND': 66.94,
#     'GEOMETRIC_RMSE_MODEL': 8.639,
#     'ROLL_ANGLE': -0.001,
#     'COLLECTION_NUMBER': 2,
#     'DATE_PRODUCT_GENERATED': 1715369882000,
#     'L1_REQUEST_ID': '1883414_00036',
#     'DATA_SOURCE_OZONE': 'VIIRS',
#     'SATURATION_BAND_1': 'N',
#     'DATA_SOURCE_WATER_VAPOR': 'VIIRS',
#     'SATURATION_BAND_2': 'N',
#     'SATURATION_BAND_3': 'Y',
#     'IMAGE_QUALITY_OLI': 9,
#     'SATURATION_BAND_4': 'Y',
#     'LANDSAT_SCENE_ID': 'LC81210422024117LGN00',
#     'SATURATION_BAND_5': 'Y',
#     'MAP_PROJECTION': 'UTM',
#     'SATURATION_BAND_6': 'Y',
#     'SENSOR_ID': 'OLI_TIRS',
#     'SATURATION_BAND_7': 'Y',
#     'SATURATION_BAND_8': 'N',
#     'WRS_PATH': 121,
#     'SATURATION_BAND_9': 'N',
#     'TARGET_WRS_PATH': 121,
#     'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802,
#     'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_121042_20240426_20240510_02_T1',
#     'PROCESSING_LEVEL': 'L2SP',
#     'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.6.0',
#     'GROUND_CONTROL_POINTS_MODEL': 85,
#     'SPACECRAFT_ID': 'LANDSAT_8',
#     'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418,
#     'GEOMETRIC_RMSE_MODEL_Y': 6.58,
#     'REFLECTIVE_LINES': 7831,
#     'GEOMETRIC_RMSE_MODEL_X': 5.599,
#     'THERMAL_SAMPLES': 7671,
#     'system:asset_size': 1121650663,
#     'DATA_SOURCE_AIR_TEMPERATURE': 'VIIRS',
#     'system:index': 'LC08_121042_20240426'}},
#   {'type': 'Image',
#    'bands': [{'id': 'SR_B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'SR_B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'SR_B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'SR_B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'SR_B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'SR_B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'SR_B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'SR_QA_AEROSOL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'ST_B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': 149,
#       'max': 372.9999407},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'ST_ATRAN',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'ST_CDIST',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'ST_DRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'ST_EMIS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'ST_EMSD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'ST_QA',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'ST_TRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'ST_URAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'QA_PIXEL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]},
#     {'id': 'QA_RADSAT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7681, 7831],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 263685, 0, -30, 2992515]}],
# ...
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 111285, 0, -30, 2995515]},
#     {'id': 'ST_DRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 111285, 0, -30, 2995515]},
#     {'id': 'ST_EMIS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 111285, 0, -30, 2995515]},
#     {'id': 'ST_EMSD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 111285, 0, -30, 2995515]},
#     {'id': 'ST_QA',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 111285, 0, -30, 2995515]},
#     {'id': 'ST_TRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 111285, 0, -30, 2995515]},
#     {'id': 'ST_URAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 111285, 0, -30, 2995515]},
#     {'id': 'QA_PIXEL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 111285, 0, -30, 2995515]},
#     {'id': 'QA_RADSAT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 111285, 0, -30, 2995515]}],
#    'version': 1732038133571850.0,
#    'id': 'LANDSAT/LC08/C02/T1_L2/LC08_122042_20241111',
#    'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000',
#     'WRS_TYPE': 2,
#     'REFLECTANCE_ADD_BAND_1': -0.2,
#     'REFLECTANCE_ADD_BAND_2': -0.2,
#     'DATUM': 'WGS84',
#     'REFLECTANCE_ADD_BAND_3': -0.2,
#     'REFLECTANCE_ADD_BAND_4': -0.2,
#     'REFLECTANCE_ADD_BAND_5': -0.2,
#     'REFLECTANCE_ADD_BAND_6': -0.2,
#     'REFLECTANCE_ADD_BAND_7': -0.2,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[114.95723892089103, 24.939633666591423],
#       [114.95906266511956, 24.946268411346974],
#       [114.99375972495798, 25.082574361536203],
#       [115.05153583858785, 25.310698286820553],
#       [115.20747845942638, 25.923391225163524],
#       [115.24795591927729, 26.08177292346621],
#       [115.3249053949423, 26.381930944273893],
#       [115.37031903267103, 26.558854857293916],
#       [115.39885587788164, 26.670357733528753],
#       [113.57463885377878, 27.035969820633667],
#       [113.55857855304775, 26.972592810285626],
#       [113.5186581629118, 26.807875488889568],
#       [113.34752255717979, 26.095136799714204],
#       [113.17679765949124, 25.37760298396999],
#       [113.16795527835383, 25.33962449580153],
#       [113.16040981589613, 25.306208211235994],
#       [113.16808468869637, 25.304674993255055],
#       [113.53148375521721, 25.232502394936333],
#       [114.64503614325253, 25.00508285968039],
#       [114.95723892089103, 24.939633666591423]]},
#     'REFLECTIVE_SAMPLES': 7741,
#     'GROUND_CONTROL_POINTS_VERSION': 5,
#     'SUN_AZIMUTH': 155.12741582,
#     'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#     'UTM_ZONE': 50,
#     'DATE_ACQUIRED': '2024-11-11',
#     'ELLIPSOID': 'WGS84',
#     'system:time_end': 1731293479868,
#     'DATA_SOURCE_PRESSURE': 'Calculated',
#     'LANDSAT_PRODUCT_ID': 'LC08_L2SP_122042_20241111_20241118_02_T1',
#     'STATION_ID': 'LGN',
#     'TEMPERATURE_ADD_BAND_ST_B10': 149,
#     'DATA_SOURCE_REANALYSIS': 'GEOS-5 IT',
#     'REFLECTANCE_MULT_BAND_7': 2.75e-05,
#     'system:time_start': 1731293479868,
#     'REFLECTANCE_MULT_BAND_6': 2.75e-05,
#     'L1_PROCESSING_LEVEL': 'L1TP',
#     'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'L1_DATE_PRODUCT_GENERATED': '2024-11-18T22:44:13Z',
#     'ORIENTATION': 'NORTH_UP',
#     'REFLECTANCE_MULT_BAND_1': 2.75e-05,
#     'WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_3': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_2': 2.75e-05,
#     'TARGET_WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_5': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_4': 2.75e-05,
#     'THERMAL_LINES': 7881,
#     'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#     'GRID_CELL_SIZE_THERMAL': 30,
#     'IMAGE_QUALITY_TIRS': 9,
#     'TRUNCATION_OLI': 'UPPER',
#     'NADIR_OFFNADIR': 'NADIR',
#     'CLOUD_COVER': 38.52,
#     'REQUEST_ID': '1964383_00023',
#     'EARTH_SUN_DISTANCE': 0.9900254,
#     'GEOMETRIC_RMSE_VERIFY': 4.224,
#     'TIRS_SSM_MODEL': 'FINAL',
#     'COLLECTION_CATEGORY': 'T1',
#     'SCENE_CENTER_TIME': '02:51:19.8686090Z',
#     'GRID_CELL_SIZE_REFLECTIVE': 30,
#     'SUN_ELEVATION': 42.76117871,
#     'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.5.0',
#     'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941,
#     'CLOUD_COVER_LAND': 38.52,
#     'GEOMETRIC_RMSE_MODEL': 6.534,
#     'ROLL_ANGLE': 0,
#     'COLLECTION_NUMBER': 2,
#     'DATE_PRODUCT_GENERATED': 1731971045000,
#     'L1_REQUEST_ID': '1964383_00023',
#     'DATA_SOURCE_OZONE': 'VIIRS',
#     'SATURATION_BAND_1': 'Y',
#     'DATA_SOURCE_WATER_VAPOR': 'VIIRS',
#     'SATURATION_BAND_2': 'Y',
#     'SATURATION_BAND_3': 'Y',
#     'IMAGE_QUALITY_OLI': 9,
#     'SATURATION_BAND_4': 'Y',
#     'LANDSAT_SCENE_ID': 'LC81220422024316LGN00',
#     'SATURATION_BAND_5': 'Y',
#     'MAP_PROJECTION': 'UTM',
#     'SATURATION_BAND_6': 'Y',
#     'SENSOR_ID': 'OLI_TIRS',
#     'SATURATION_BAND_7': 'Y',
#     'SATURATION_BAND_8': 'N',
#     'WRS_PATH': 122,
#     'SATURATION_BAND_9': 'N',
#     'TARGET_WRS_PATH': 122,
#     'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802,
#     'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_122042_20241111_20241118_02_T1',
#     'PROCESSING_LEVEL': 'L2SP',
#     'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.6.0',
#     'GROUND_CONTROL_POINTS_MODEL': 398,
#     'SPACECRAFT_ID': 'LANDSAT_8',
#     'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418,
#     'GEOMETRIC_RMSE_MODEL_Y': 4.506,
#     'REFLECTIVE_LINES': 7881,
#     'GEOMETRIC_RMSE_MODEL_X': 4.732,
#     'THERMAL_SAMPLES': 7741,
#     'system:asset_size': 1097961823,
#     'DATA_SOURCE_AIR_TEMPERATURE': 'VIIRS',
#     'GROUND_CONTROL_POINTS_VERIFY': 145,
#     'system:index': 'LC08_122042_20241111'}},
#   {'type': 'Image',
#    'bands': [{'id': 'SR_B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'SR_B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'SR_B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'SR_B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'SR_B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'SR_B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'SR_B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': -0.2,
#       'max': 1.6022125},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'SR_QA_AEROSOL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'ST_B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'double',
#       'min': 149,
#       'max': 372.9999407},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'ST_ATRAN',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'ST_CDIST',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'ST_DRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'ST_EMIS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'ST_EMSD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'ST_QA',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'ST_TRAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'ST_URAD',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': -32768,
#       'max': 32767},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'QA_PIXEL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]},
#     {'id': 'QA_RADSAT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [7741, 7881],
#      'crs': 'EPSG:32650',
#      'crs_transform': [30, 0, 110985, 0, -30, 2995515]}],
#    'version': 1736012870526581,
#    'id': 'LANDSAT/LC08/C02/T1_L2/LC08_122042_20241229',
#    'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000',
#     'WRS_TYPE': 2,
#     'REFLECTANCE_ADD_BAND_1': -0.2,
#     'REFLECTANCE_ADD_BAND_2': -0.2,
#     'DATUM': 'WGS84',
#     'REFLECTANCE_ADD_BAND_3': -0.2,
#     'REFLECTANCE_ADD_BAND_4': -0.2,
#     'REFLECTANCE_ADD_BAND_5': -0.2,
#     'REFLECTANCE_ADD_BAND_6': -0.2,
#     'REFLECTANCE_ADD_BAND_7': -0.2,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[113.15661015509912, 25.30609415821921],
#       [113.16663500073417, 25.304091635955857],
#       [113.39325146077475, 25.25922329430347],
#       [114.44720357750222, 25.045409287613523],
#       [114.9538743920896, 24.93962142941302],
#       [114.95850203636277, 24.95764660175639],
#       [114.98698266393463, 25.06934356933494],
#       [115.00486631353793, 25.139999429471445],
#       [115.20247450586535, 25.91764214663784],
#       [115.24180908788439, 26.07167797605117],
#       [115.31961316232254, 26.375377215716348],
#       [115.36578080515307, 26.55518913994745],
#       [115.39524515475968, 26.670339792011493],
#       [115.01231524372078, 26.74922800246649],
#       [114.00712654568338, 26.95078786626559],
#       [113.57069659091425, 27.035804651556212],
#       [113.55552089412926, 26.976136548212256],
#       [113.51366852583867, 26.803423540221075],
#       [113.34867159073815, 26.11599849275663],
#       [113.16699696860469, 25.351989378594038],
#       [113.15661015509912, 25.30609415821921]]},
#     'REFLECTIVE_SAMPLES': 7741,
#     'GROUND_CONTROL_POINTS_VERSION': 5,
#     'SUN_AZIMUTH': 153.23825745,
#     'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#     'UTM_ZONE': 50,
#     'DATE_ACQUIRED': '2024-12-29',
#     'ELLIPSOID': 'WGS84',
#     'system:time_end': 1735440681087,
#     'DATA_SOURCE_PRESSURE': 'Calculated',
#     'LANDSAT_PRODUCT_ID': 'LC08_L2SP_122042_20241229_20250104_02_T1',
#     'STATION_ID': 'LGN',
#     'TEMPERATURE_ADD_BAND_ST_B10': 149,
#     'DATA_SOURCE_REANALYSIS': 'GEOS-5 IT',
#     'REFLECTANCE_MULT_BAND_7': 2.75e-05,
#     'system:time_start': 1735440681087,
#     'REFLECTANCE_MULT_BAND_6': 2.75e-05,
#     'L1_PROCESSING_LEVEL': 'L1TP',
#     'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'L1_DATE_PRODUCT_GENERATED': '2025-01-04T01:29:30Z',
#     'ORIENTATION': 'NORTH_UP',
#     'REFLECTANCE_MULT_BAND_1': 2.75e-05,
#     'WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_3': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_2': 2.75e-05,
#     'TARGET_WRS_ROW': 42,
#     'REFLECTANCE_MULT_BAND_5': 2.75e-05,
#     'REFLECTANCE_MULT_BAND_4': 2.75e-05,
#     'THERMAL_LINES': 7881,
#     'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#     'GRID_CELL_SIZE_THERMAL': 30,
#     'IMAGE_QUALITY_TIRS': 9,
#     'TRUNCATION_OLI': 'UPPER',
#     'NADIR_OFFNADIR': 'NADIR',
#     'CLOUD_COVER': 0.04,
#     'REQUEST_ID': '1980278_00018',
#     'EARTH_SUN_DISTANCE': 0.9834094,
#     'GEOMETRIC_RMSE_VERIFY': 4.082,
#     'TIRS_SSM_MODEL': 'FINAL',
#     'COLLECTION_CATEGORY': 'T1',
#     'SCENE_CENTER_TIME': '02:51:21.0877880Z',
#     'GRID_CELL_SIZE_REFLECTIVE': 30,
#     'SUN_ELEVATION': 35.8370469,
#     'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.5.0',
#     'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941,
#     'CLOUD_COVER_LAND': 0.04,
#     'GEOMETRIC_RMSE_MODEL': 7.406,
#     'ROLL_ANGLE': -0.001,
#     'COLLECTION_NUMBER': 2,
#     'DATE_PRODUCT_GENERATED': 1735955700000,
#     'L1_REQUEST_ID': '1980278_00018',
#     'DATA_SOURCE_OZONE': 'VIIRS',
#     'SATURATION_BAND_1': 'N',
#     'DATA_SOURCE_WATER_VAPOR': 'VIIRS',
#     'SATURATION_BAND_2': 'N',
#     'SATURATION_BAND_3': 'N',
#     'IMAGE_QUALITY_OLI': 9,
#     'SATURATION_BAND_4': 'N',
#     'LANDSAT_SCENE_ID': 'LC81220422024364LGN00',
#     'SATURATION_BAND_5': 'N',
#     'MAP_PROJECTION': 'UTM',
#     'SATURATION_BAND_6': 'Y',
#     'SENSOR_ID': 'OLI_TIRS',
#     'SATURATION_BAND_7': 'Y',
#     'SATURATION_BAND_8': 'N',
#     'WRS_PATH': 122,
#     'SATURATION_BAND_9': 'N',
#     'TARGET_WRS_PATH': 122,
#     'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_16.4.0',
#     'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802,
#     'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_122042_20241229_20250104_02_T1',
#     'PROCESSING_LEVEL': 'L2SP',
#     'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.6.0',
#     'GROUND_CONTROL_POINTS_MODEL': 720,
#     'SPACECRAFT_ID': 'LANDSAT_8',
#     'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418,
#     'GEOMETRIC_RMSE_MODEL_Y': 5.682,
#     'REFLECTIVE_LINES': 7881,
#     'GEOMETRIC_RMSE_MODEL_X': 4.75,
#     'THERMAL_SAMPLES': 7741,
#     'system:asset_size': 990260176,
#     'DATA_SOURCE_AIR_TEMPERATURE': 'VIIRS',
#     'GROUND_CONTROL_POINTS_VERIFY': 226,
#     'system:index': 'LC08_122042_20241229'}}]}

# %% [markdown]
# ### 影像集的信息提取

# %%
imgid = Landsat8.aggregate_array('system:index')    # 获取 Landsat 8 图像集合中所有影像的 ID
imgtime = Landsat8.aggregate_array('system:time_start')    # 获取影像的时间戳
imgsize = Landsat8.size()    # 获取影像数量
print(imgid.getInfo())
print(imgtime.getInfo())
print(f"影像数量: {imgsize.getInfo()}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['LC08_121042_20240105', 'LC08_121042_20240325', 'LC08_121042_20240410', 'LC08_121042_20240426', 'LC08_121042_20240528', 'LC08_121042_20240629', 'LC08_121042_20240715', 'LC08_121042_20240901', 'LC08_121042_20240917', 'LC08_121042_20241003', 'LC08_121042_20241019', 'LC08_121042_20241104', 'LC08_121042_20241222', 'LC08_122042_20240112', 'LC08_122042_20240706', 'LC08_122042_20240807', 'LC08_122042_20240823', 'LC08_122042_20240908', 'LC08_122042_20241010', 'LC08_122042_20241111', 'LC08_122042_20241229']
# [1704422712403, 1711334688213, 1712717083755, 1714099474593, 1716864251368, 1719629065822, 1721011477064, 1725158697979, 1726541104231, 1727923499997, 1729305913140, 1730688307167, 1734835511301, 1705027886779, 1720234239841, 1722999051591, 1724381464833, 1725763873342, 1728528676176, 1731293479868, 1735440681087]
# 影像数量: 21

# %% [markdown]
# ### 获取影像集中的影像

# %%
# 获取影像集中的第一张影像
print(type(Landsat8))    # 输出类型为 ee.ImageCollection
first_image = Landsat8.first()
print(type(first_image))    # 输出类型为 ee.Image
first_image    # 输出第一张影像的信息
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'ee.imagecollection.ImageCollection'>
# <class 'ee.image.Image'>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><label class='ee-shut'>Image LANDSAT/LC08/C02/T1_L2/LC08_121042_20240105 (19 bands)<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>LANDSAT/LC08/C02/T1_L2/LC08_121042_20240105</span></li><li><span class='ee-k'>version:</span><span class='ee-v'>1705189124176658</span></li><li><label class='ee-shut'>bands: List (19 elements)<input type='checkbox' class='ee-toggle'></label><ul><li><label class='ee-shut'>0: "SR_B1", double, EPSG:32650, 7681x7821 px<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>id:</span><span class='ee-v'>SR_B1</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:32650</span></li><li><label class='ee-shut'>crs_transform: [30, 0, 267285, 0, -30, 2992215]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>30</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>267285</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>-30</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>2992215</span></li></ul></li><li><label class='ee-shut'>data_type: double<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>1.6022125</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>-0.2</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>double</span></li></ul></li><li><label class='ee-shut'>dimensions: [7681, 7821]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>7681</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>7821</span></li></ul></li></ul></li><li><label class='ee-shut'>1: "SR_B2", double, EPSG:32650, 7681x7821 px<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>id:</span><span class='ee-v'>SR_B2</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:32650</span></li><li><label class='ee-shut'>crs_transform: [30, 0, 267285, 0, -30, 2992215]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>30</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>267285</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>-30</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>2992215</span></li></ul></li><li><label class='ee-shut'>data_type: double<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>1.6022125</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>-0.2</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>double</span></li></ul></li><li><label class='ee-shut'>dimensions: [7681, 7821]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>7681</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>7821</span></li></ul></li></ul></li><li><label class='ee-shut'>2: "SR_B3", double, EPSG:32650, 7681x7821 px<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>id:</span><span class='ee-v'>SR_B3</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:32650</span></li><li><label class='ee-shut'>crs_transform: [30, 0, 267285, 0, -30, 2992215]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>30</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span clas ...

# %%
# 获取影像集中的指定影像
imglist = Landsat8.toList(imgsize)    # 将影像集转换为 ee.List
img = ee.Image(imglist.get(4))    # 获取第五张影像
# for index in range(imgsize.getInfo()):
#     img = ee.Image(imglist.get(index))
#     date = ee.Date(img.get('system:time_start')).format('YYYY-MM-dd').getInfo()
#     geemap.download_ee_image(img, filename=f"D:/学科作业/geemap/数据/于都县/{date}.tif", scale=30)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
for layer in ['江西省(本地矢量数据)', '江西省（资产）', 'Landsat 8']:
    Map.remove(layer)    # 移除之前添加的图层
Map.addLayer(first_image, visualization, "Landsat 8 (First Image)")    # 添加第一张影像到地图
Map.addLayer(img, visualization, "Landsat 8 (Image 4)")    # 添加第四张影像到地图
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=28361.0, center=[25.02090651422749, 115.11474609375], controls=(WidgetControl(options=['position', …

# %% [markdown]
# ### 从添加的单张影像数据中可以看出，单个影像的效果比较差，因此需要进行影像集的合成

# %% [markdown]
# ### 常用合成方式如下，合成之后的影像集转换为 ee.Image 类型

# %%
Landsat8_max = Landsat8.max()    # 获取 Landsat 8 图像集合的最大值合成
Landsat8_min = Landsat8.min()    # 获取 Landsat 8 图像集合的最小值合成
Landsat8_mean = Landsat8.mean()    # 获取 Landsat 8 图像集合的平均值合成
Landsat8_median = Landsat8.median()    # 获取 Landsat 8 图像集合的中位数合成
type(Landsat8_max)    # 输出类型为 ee.Image
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ee.image.Image

# %%
# clip 函数可以将影像裁剪到指定区域，不可以对 ee.ImageCollection 使用
# buffer 函数用于对 ee.Feature 或 ee.Geometry 扩展缓冲区，在下载影像时通常需要进行缓冲区扩展
roi = yudu.geometry().buffer(1000)
Map.addLayer(Landsat8_mean.clip(roi), visualization, "Landsat 8 (Mean)")    # 添加平均值值合成到地图
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=7184.0, center=[27.605670826465445, 115.7080078125], controls=(WidgetControl(options=['position', '…

# %% [markdown]
# ### 影像波段的选取 **select** 函数的用法

# %%
# 影像中通常存在许多波段，可以使用 select 函数选择需要的波段并更名
print(Landsat8_max.bandNames().getInfo())    # 打印影像的波段名称
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7', 'SR_QA_AEROSOL', 'ST_B10', 'ST_ATRAN', 'ST_CDIST', 'ST_DRAD', 'ST_EMIS', 'ST_EMSD', 'ST_QA', 'ST_TRAD', 'ST_URAD', 'QA_PIXEL', 'QA_RADSAT']

# %%
# 选择 红、绿、蓝 波段并重命名
rgb = Landsat8_max.select(['SR_B4', 'SR_B3', 'SR_B2'], ['Red', 'Green', 'Blue'])
print(rgb.bandNames().getInfo())    # 打印重命名后的波段名称
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['Red', 'Green', 'Blue']

# %% [markdown]
# ### 在上面展示的 **select** 操作中，实现了 **3** 个功能：
# ---
# 1. 挑选部分波段
# 2. 为波段更名
# 3. 修改波段顺序
# ---
# ### **select** 函数的核心功能便在于此

# %% [markdown]
# ## 在日常使用中，对影像集的处理通常不进行拆分，而是在一处统一完成

# %%
visualization = {'bands': ['Nir', 'Red', 'Green'], 'min': 0.0, 'max': 0.3}    # 可视化参数
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
img = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2") \
                .filterBounds(yudu) \
                .filterDate(ee.Date('2024-01-01'), ee.Date('2024-12-31')) \
                .map(maskL8sr) \
                .max() \
                .select(['SR_B5', 'SR_B4', 'SR_B3'], ['Nir', 'Red', 'Green']) \
                .clip(roi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map.addLayer(img, visualization, "Landsat 8 (Max False Color )")    # 添加最大值合成的 假彩色 图像到地图
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=28090.0, center=[26.362342068998764, 115.10375976562501], controls=(WidgetControl(options=['positio…
